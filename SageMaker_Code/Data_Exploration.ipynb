# %%
import pandas as pd
import boto3
import sagemaker

sess = sagemaker.Session()
bucket = sess.default_bucket()
role = sagemaker.get_execution_role()
region = boto3.Session().region_name

# %% [markdown]
# # Download the datasets

# %%
# !aws s3 cp 's3://ads508-team4-master/result_demo.csv' ./data/
# Out:
# download: s3://ads508-team4-master/result_demo.csv to data/result_demo.csv

# %%
# !aws s3 cp 's3://ads508-team4-master/result_psych.csv' ./data/
# Out:
# download: s3://ads508-team4-master/result_psych.csv to data/result_psych.csv

# %%
import csv

df_demo = pd.read_csv(
    "./data/result_demo.csv",
    delimiter=",",
    quoting=csv.QUOTE_NONE,
)
df_demo = df_demo.iloc[:,1:]
df_demo.head(100)
# Out:
#         user_id platform_x       level_1 level_2  level_3 confidence_score  \
# 0   1.71799e+10    android  Demographics  Income   Medium                1
# 1   3.43597e+10    android  Demographics  Income   Medium                1
# 2   1.71799e+10    android  Demographics  Income      Low                1
# 3   1.71799e+10    android  Demographics     Age  25 - 34                1
# 4   1.71799e+10    android  Demographics  Gender     Male         0.993641
# ..          ...        ...           ...     ...      ...              ...
# 95  2.57698e+10    android  Demographics  Income   Medium                1
# 96  8.58993e+10    android  Demographics  Income      Low                1
# 97  7.73094e+10        web  Demographics  Gender     Male          0.93838
# 98  7.73094e+10        web  Demographics     Age  18 - 24                1
# 99  8.58993e+10        iOS  Demographics  Income   Medium                1
#
#    country_code platform_y asset_id minutes_viewed showtype  \
# 0            PH    android    14707             55   Movies
# 1            PH    android    14707             92   Movies
# 2            PH    android    14707             76   Movies
# 3            PH    android    14707             76   Movies
# 4            PH    android    14707             76   Movies
# ..          ...        ...      ...            ...      ...
# 95           PH    android    14734             80   Movies
# 96           PH    android    14734            112   Movies
# 97           PH        web    14734             92   Movies
# 98           PH        web    14734             92   Movies
# 99           PH        iOS    14734              6   Movies
#
#                    genre running_minutes source_language season_id series_id  \
# 0   Action and Adventure             103         Tagalog       NaN       NaN
# 1   Action and Adventure             103         Tagalog       NaN       NaN
# 2   Action and Adventure             103         Tagalog       NaN       NaN
# 3   Action and Adventure             103         Tagalog       NaN       NaN
# 4   Action and Adventure             103         Tagalog       NaN       NaN
# ..                   ...             ...             ...       ...       ...
# 95                 Drama             116         Tagalog       NaN       NaN
# 96                 Drama             116         Tagalog       NaN       NaN
# 97                 Drama             116         Tagalog       NaN       NaN
# 98                 Drama             116         Tagalog       NaN       NaN
# 99                 Drama             116         Tagalog       NaN       NaN
#
#    studio_id
# 0        448
# 1        448
# 2        448
# 3        448
# 4        448
# ..       ...
# 95       448
# 96       448
# 97       448
# 98       448
# 99       448
#
# [100 rows x 17 columns]

# %%
df_psych = pd.read_csv(
    "./data/result_psych.csv",
    delimiter=",",
    quoting=csv.QUOTE_NONE,
)
df_psych = df_psych.iloc[:,1:]
df_psych.head(100)
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1,6,9,10,13,15,16,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         user_id platform_x       level_1 level_2  level_3 confidence_score  \
# 0   1.71799e+10    android  Demographics  Income   Medium                1
# 1   3.43597e+10    android  Demographics  Income   Medium                1
# 2   1.71799e+10    android  Demographics  Income      Low                1
# 3   1.71799e+10    android  Demographics     Age  25 - 34                1
# 4   1.71799e+10    android  Demographics  Gender     Male         0.993641
# ..          ...        ...           ...     ...      ...              ...
# 95  2.57698e+10    android  Demographics  Income   Medium                1
# 96  8.58993e+10    android  Demographics  Income      Low                1
# 97  7.73094e+10        web  Demographics  Gender     Male          0.93838
# 98  7.73094e+10        web  Demographics     Age  18 - 24                1
# 99  8.58993e+10        iOS  Demographics  Income   Medium                1
#
#    country_code platform_y asset_id minutes_viewed showtype  \
# 0            PH    android    14707             55   Movies
# 1            PH    android    14707             92   Movies
# 2            PH    android    14707             76   Movies
# 3            PH    android    14707             76   Movies
# 4            PH    android    14707             76   Movies
# ..          ...        ...      ...            ...      ...
# 95           PH    android    14734             80   Movies
# 96           PH    android    14734            112   Movies
# 97           PH        web    14734             92   Movies
# 98           PH        web    14734             92   Movies
# 99           PH        iOS    14734              6   Movies
#
#                    genre running_minutes source_language season_id series_id  \
# 0   Action and Adventure             103         Tagalog       NaN       NaN
# 1   Action and Adventure             103         Tagalog       NaN       NaN
# 2   Action and Adventure             103         Tagalog       NaN       NaN
# 3   Action and Adventure             103         Tagalog       NaN       NaN
# 4   Action and Adventure             103         Tagalog       NaN       NaN
# ..                   ...             ...             ...       ...       ...
# 95                 Drama             116         Tagalog       NaN       NaN
# 96                 Drama             116         Tagalog       NaN       NaN
# 97                 Drama             116         Tagalog       NaN       NaN
# 98                 Drama             116         Tagalog       NaN       NaN
# 99                 Drama             116         Tagalog       NaN       NaN
#
#    studio_id
# 0        448
# 1        448
# 2        448
# 3        448
# 4        448
# ..       ...
# 95       448
# 96       448
# 97       448
# 98       448
# 99       448
#
# [100 rows x 17 columns]
